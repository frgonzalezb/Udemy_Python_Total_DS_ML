# %% [markdown]
# # Árboles de Decisión - Parte II (1)
# Dado el modelo creado, entrenado y empleando el gráfico de árbol de decisión del Ejercicio 3
#
# Completa el código proporcionado para lograr el paso siguiente:
#
# Utiliza el parámetro adecuando de `plot_tree` para colorear los nodos para representar las clases del árbol.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

from data.iris_info import iris_dict
# from iris_info import iris_dict  # Udemy usa esto!!

# Convertir el diccionario que contiene los datos del dataset iris en un DataFrame de pandas para facilitar su manipulación.
iris_df = pd.DataFrame(iris_dict)

# Preparar el DataFrame para modelado, eliminando la columna 'species' y usando el resto como características (X).
X = iris_df.drop("species", axis=1)

# Inicializar el codificador de etiquetas y transformar las etiquetas categóricas de especies en valores numéricos.
le = LabelEncoder()
especies = le.fit_transform(iris_df["species"])
y = especies

# División de datos en conjunto de entrenamiento y de prueba
X_entrena, X_prueba, y_entrena, y_prueba = train_test_split(X, y, train_size=0.8, random_state=42)

# Creación y entrenamiento del modelo de árbol de decisión
arbol = DecisionTreeClassifier()
arbol.fit(X_entrena, y_entrena)

# Visualización del árbol de decisión
plt.figure(figsize=(20, 20))
plot_tree(decision_tree=arbol, filled=True)
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'x[3] <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.38461538461538464, 0.7857142857142857, 'x[2] <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]'),
#  Text(0.15384615384615385, 0.6428571428571429, 'x[3] <= 1.65\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6153846153846154, 0.6428571428571429, 'x[3] <= 1.75\ngini = 0.206\nsamples = 43\nvalue = [0, 5, 38]'),
#  Text(0.38461538461538464, 0.5, 'x[2] <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(0.3076923076923077, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.46153846153846156, 0.35714285714285715, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.21428571428571427, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5, 'x[2] <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]'),
#  Text(0.7692307692307693, 0.35714285714285715, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.35714285714285715, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]')]

# %% [markdown]
# # Árboles de Decisión - Parte II (2)
# Dado el modelo creado, entrenado y empleando el gráfico de árbol de decisión del  Ejercicio 1
#
# Completa el código proporcionado para lograr el paso siguiente:
#
# Utiliza el parámetro adecuando de `plot_tree` mostrar los nombres de las especies en los nodos, haciendo la visualización más clara y entendible.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

from data.iris_info import iris_dict
# from iris_info import iris_dict  # Udemy usa esto!!

# Convertir el diccionario que contiene los datos del dataset iris en un DataFrame de pandas para facilitar su manipulación.
iris_df = pd.DataFrame(iris_dict)

# Preparar el DataFrame para modelado, eliminando la columna 'species' y usando el resto como características (X).
X = iris_df.drop("species", axis=1)

# Inicializar el codificador de etiquetas y transformar las etiquetas categóricas de especies en valores numéricos.
le = LabelEncoder()
especies = le.fit_transform(iris_df["species"])
y = especies

# División de datos en conjunto de entrenamiento y de prueba
X_entrena, X_prueba, y_entrena, y_prueba = train_test_split(X, y, train_size=0.8, random_state=42)

# Creación y entrenamiento del modelo de árbol de decisión
arbol = DecisionTreeClassifier()
arbol.fit(X_entrena, y_entrena)

# Visualización del árbol de decisión
plt.figure(figsize=(20, 20))
plot_tree(decision_tree=arbol, filled=True, class_names=list(iris_df['species'].unique()))
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'x[2] <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(0.38461538461538464, 0.7857142857142857, 'x[2] <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]\nclass = versicolor'),
#  Text(0.15384615384615385, 0.6428571428571429, 'x[3] <= 1.65\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]\nclass = versicolor'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.6153846153846154, 0.6428571428571429, 'x[3] <= 1.75\ngini = 0.206\nsamples = 43\nvalue = [0, 5, 38]\nclass = virginica'),
#  Text(0.38461538461538464, 0.5, 'x[2] <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(0.3076923076923077, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.46153846153846156, 0.35714285714285715, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(0.38461538461538464, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(0.5384615384615384, 0.21428571428571427, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(0.46153846153846156, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.6153846153846154, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.8461538461538461, 0.5, 'x[2] <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]\nclass = virginica'),
#  Text(0.7692307692307693, 0.35714285714285715, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.6923076923076923, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.8461538461538461, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.9230769230769231, 0.35714285714285715, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]\nclass = virginica')]

# %% [markdown]
# # Árboles de Decisión - Parte II (3)
# Dado el modelo creado, entrenado y empleando el gráfico de árbol de decisión del  Ejercicio 2
#
# Completa el código proporcionado para lograr el paso siguiente:
#
# Utiliza el parámetro adecuando de `plot_tree` para mostrar los nombres de las características del DataFrame para etiquetar los nodos, facilitando la identificación de las divisiones.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

from data.iris_info import iris_dict
# from iris_info import iris_dict  # Udemy usa esto!!

# Convertir el diccionario que contiene los datos del dataset iris en un DataFrame de pandas para facilitar su manipulación.
iris_df = pd.DataFrame(iris_dict)

# Preparar el DataFrame para modelado, eliminando la columna 'species' y usando el resto como características (X).
X = iris_df.drop("species", axis=1)

# Inicializar el codificador de etiquetas y transformar las etiquetas categóricas de especies en valores numéricos.
le = LabelEncoder()
especies = le.fit_transform(iris_df["species"])
y = especies

# División de datos en conjunto de entrenamiento y de prueba
X_entrena, X_prueba, y_entrena, y_prueba = train_test_split(X, y, train_size=0.8, random_state=42)

# Creación y entrenamiento del modelo de árbol de decisión
arbol = DecisionTreeClassifier()
arbol.fit(X_entrena, y_entrena)

# Visualización del árbol de decisión
plt.figure(figsize=(20, 20))
plot_tree(
    decision_tree=arbol,
    filled=True,
    class_names=list(iris_df['species'].unique()),
    feature_names=iris_df.columns.to_list()
)
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'petal_length <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(0.38461538461538464, 0.7857142857142857, 'petal_length <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]\nclass = versicolor'),
#  Text(0.15384615384615385, 0.6428571428571429, 'petal_width <= 1.65\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]\nclass = versicolor'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.6153846153846154, 0.6428571428571429, 'petal_width <= 1.75\ngini = 0.206\nsamples = 43\nvalue = [0, 5, 38]\nclass = virginica'),
#  Text(0.38461538461538464, 0.5, 'petal_length <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(0.3076923076923077, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.46153846153846156, 0.35714285714285715, 'petal_width <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(0.38461538461538464, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(0.5384615384615384, 0.21428571428571427, 'petal_length <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(0.46153846153846156, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.6153846153846154, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.8461538461538461, 0.5, 'petal_length <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]\nclass = virginica'),
#  Text(0.7692307692307693, 0.35714285714285715, 'sepal_length <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.6923076923076923, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.8461538461538461, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.9230769230769231, 0.35714285714285715, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]\nclass = virginica')]
